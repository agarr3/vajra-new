# %% [markdown]
# <a href="https://colab.research.google.com/github/agarr3/vajra-new/blob/main/AE_HYBRID_LSTM_V4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from tqdm import tqdm_notebook as tqdm
from sklearn.preprocessing import LabelEncoder
from PIL import Image
import matplotlib.pyplot as plt
import torch
# Neural networks can be constructed using the torch.nn package.
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset
import torchvision
import torchvision.transforms as transforms

import IPython.display as ipd

import random

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#settings
batch_size = 64
validation_split = .3
shuffle_dataset = True
random_seed= 42
reduction_loss = "mean"
if reduction_loss == "mean":
  criterion = nn.MSELoss(reduction="mean")
elif reduction_loss == "sum":
  criterion = nn.MSELoss(reduction="sum")
n_epochs = 30
print_every = 1

BASE_PATH = "/content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA"

input_bins = 12
seq_len=200
AE_encoded_dim = 64

class_level_loss_mode = "test"

print(device)
# Out:
# cuda:0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
DATA_BASE_PATH = "/content/gdrive/My Drive/vajra/songs-vajra-data/"
DATA_SONG_DIR = "Chroma"
DATA_IMG_DIR = "Chroma"



files = []
western_files = []
exclusion = ["098567.npy","098569.npy", '098565.npy']
for r,d, fileList in os.walk(os.path.join(DATA_BASE_PATH, DATA_IMG_DIR, "Western_numpy")):
  for file in fileList:
    if(file not in exclusion):
      western_files.append([file,file, "Western_numpy"])
    else:
      print(file)

random.seed(1234)
western_files = random.sample(western_files, 2008)

indian_files = []
for r,d, fileList in os.walk(os.path.join(DATA_BASE_PATH, DATA_IMG_DIR, "Indian_numpy")):
  for file in fileList:
    if(True):
      indian_files.append([file,file, "Indian_numpy"])
    else:
      print(file)

files = indian_files + western_files
dataDF = pd.DataFrame(files, columns=['Images','songs','labels'])
dataDF.head()
# Out:
# 098567.npy
# 098569.npy
# 098565.npy
#                   Images                  songs        labels
# 0           Theeyame.npy           Theeyame.npy  Indian_numpy
# 1    AadedaAattamNee.npy    AadedaAattamNee.npy  Indian_numpy
# 2    ElampadiElelelo.npy    ElampadiElelelo.npy  Indian_numpy
# 3  SajanMoreGharAaye.npy  SajanMoreGharAaye.npy  Indian_numpy
# 4         Aanandhame.npy         Aanandhame.npy  Indian_numpy

# %%
if class_level_loss_mode == "all":
  indian_dataDF = pd.DataFrame(indian_files, columns=['Images','songs','labels'])
  indian_dataDF.head()
elif class_level_loss_mode == "test":
  indian_dataDF = dataDF[dataDF['labels'] == "Indian_numpy"]
  indian_dataDF = indian_dataDF.reset_index(drop=True)

# %%
if class_level_loss_mode == "all":
  western_dataDF = pd.DataFrame(western_files, columns=['Images','songs','labels'])
  western_dataDF.head()
elif class_level_loss_mode == "test":
  western_dataDF = dataDF[dataDF['labels'] == "Western_numpy"]
  western_dataDF = western_dataDF.reset_index(drop=True)

# %%
western_dataDF.groupby("labels").count()
# Out:
#                Images  songs
# labels
# Western_numpy    2008   2008

# %%
dataDF.groupby("labels").count()
# Out:
#                Images  songs
# labels
# Indian_numpy     2008   2008
# Western_numpy    2008   2008

# %%
test_idx = random. randint(0,1000)
test_img_path = os.path.join(DATA_BASE_PATH, DATA_IMG_DIR, dataDF.loc[test_idx, 'labels'], dataDF.loc[test_idx, 'Images'])
print(test_img_path)

numpy_arr = np.load(test_img_path)

import matplotlib.pyplot as plt

plt.pcolormesh(numpy_arr)
# Out:
# /content/gdrive/My Drive/vajra/songs-vajra-data/Chroma/Indian_numpy/RangeWalaJatt.npy

# %%
test_img_path = '/content/gdrive/My Drive/Kaggle/GTZAN/Data/images_original/reggae/reggae00016.png'
test_image = Image.open(test_img_path)
test_image = test_image.convert('RGB').convert('L')
test_image
# Out:
# <PIL.Image.Image image mode=L size=432x288 at 0x7FD1A61AD590>

# %%
lb = LabelEncoder()
dataDF['encoded_labels'] = lb.fit_transform(dataDF['labels'])
dataDF.head()
# Out:
#                   Images                  songs        labels  encoded_labels
# 0           Theeyame.npy           Theeyame.npy  Indian_numpy               0
# 1    AadedaAattamNee.npy    AadedaAattamNee.npy  Indian_numpy               0
# 2    ElampadiElelelo.npy    ElampadiElelelo.npy  Indian_numpy               0
# 3  SajanMoreGharAaye.npy  SajanMoreGharAaye.npy  Indian_numpy               0
# 4         Aanandhame.npy         Aanandhame.npy  Indian_numpy               0

# %%
indian_dataDF['encoded_labels'] = lb.transform(indian_dataDF['labels'])
western_dataDF['encoded_labels'] = lb.transform(western_dataDF['labels'])

# %%
indian_dataDF.groupby(by=['labels','encoded_labels']).count()
# Out:
#                              Images  songs
# labels       encoded_labels
# Indian_numpy 0                 2008   2008

# %%
classes = ('Indian_numpy', 'Western_numpy')
dataDF.groupby(by=['labels','encoded_labels']).count()
# Out:
#                               Images  songs
# labels        encoded_labels
# Indian_numpy  0                 2008   2008
# Western_numpy 1                 2008   2008

# %%
from sklearn.model_selection import train_test_split

dataDF = dataDF.sample(frac=1)
df_train, df_test = train_test_split(dataDF, test_size=validation_split, stratify=dataDF[["labels"]], random_state=9)

df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)


if class_level_loss_mode == "test":
  western_dataDF = df_test[df_test['labels'] == "Western_numpy"]
  western_dataDF = western_dataDF.reset_index(drop=True)
  indian_dataDF = df_test[df_test['labels'] == "Indian_numpy"]
  indian_dataDF = indian_dataDF.reset_index(drop=True)

# %%
df_train.groupby(by=['labels','encoded_labels']).count()
# Out:
#                               Images  songs
# labels        encoded_labels
# Indian_numpy  0                 1405   1405
# Western_numpy 1                 1406   1406

# %%
df_test.groupby(by=['labels','encoded_labels']).count()
# Out:
#                               Images  songs
# labels        encoded_labels
# Indian_numpy  0                  603    603
# Western_numpy 1                  602    602

# %%
indian_dataDF.groupby(by=['labels','encoded_labels']).count()
# Out:
#                              Images  songs
# labels       encoded_labels
# Indian_numpy 0                  603    603

# %%
transform_normal = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

transform = transforms.Compose(
    [transforms.ToTensor()])

# %%
class MEL_Dataset(Dataset):
    def __init__(self, img_data,img_path,transform=None):
        self.img_path = img_path
        self.transform = transform
        self.img_data = img_data
        
    def __len__(self):
        return len(self.img_data)
    
    def __getitem__(self, index):
        img_name = os.path.join(self.img_path,self.img_data.loc[index, 'labels'],
                                self.img_data.loc[index, 'Images'])
        image = np.load(img_name)
        data = torch.tensor(image[:,:seq_len], dtype=torch.float)
        data = data.permute(1, 0)
        label = torch.tensor(self.img_data.loc[index, 'encoded_labels'])
        return data, label

# %%
train_dataset = MEL_Dataset(df_train,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)
test_dataset = MEL_Dataset(df_test,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)

# %%
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size)
testloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size)

# %%
indian_dataset = MEL_Dataset(indian_dataDF,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)
western_dataset = MEL_Dataset(western_dataDF,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)

indian_loader = torch.utils.data.DataLoader(indian_dataset, batch_size=batch_size)
western_loader = torch.utils.data.DataLoader(western_dataset, batch_size=batch_size)

# %%
len(indian_dataset)
# Out:
# 603

# %%
def mel_display(S_DB):
    S_DB = S_DB.numpy()
    array = S_DB*-1
    array *= (255.0/array.max())
    #array = 255 - array
    array = np.transpose(array, (2, 1, 0))
    return array.squeeze()

# %%
# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        ax.pcolormesh(image.permute(1, 0)) # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
# get some random training images
dataiter = iter(testloader)
images, labels = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        ax.pcolormesh(image.permute(1, 0)) # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
# get some random training images
dataiter = iter(indian_loader)
images, labels = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        ax.pcolormesh(image.permute(1, 0)) # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
# get some random training images
dataiter = iter(western_loader)
images, labels = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        ax.pcolormesh(image.permute(1, 0)) # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
class Encoder(torch.nn.Module):
  def __init__(self, seq_len, n_features, embedding_dim=64, kernel_size=[4,3,2], stride=[1,1,1]):
    super(Encoder, self).__init__()
    self.seq_len, self.n_features = seq_len, n_features
    self.embedding_dim, self.hidden_dim = embedding_dim, 2 * embedding_dim


    self.conv = nn.Conv1d(in_channels=seq_len,out_channels=seq_len,kernel_size=kernel_size[0],stride=stride[0], groups=seq_len)
    conv_op_dim = int(((n_features - kernel_size[0])/ stride[0]) + 1)

    self.conv_1 = nn.Conv1d(in_channels=seq_len,out_channels=seq_len,kernel_size=kernel_size[1],stride=stride[1], groups=seq_len)
    conv_op_dim1 = int(((conv_op_dim - kernel_size[1])/ stride[1]) + 1)

    self.conv_2 = nn.Conv1d(in_channels=seq_len,out_channels=seq_len,kernel_size=kernel_size[2],stride=stride[2], groups=seq_len)
    conv_op_dim2 = int(((conv_op_dim1 - kernel_size[2])/ stride[2]) + 1)

    self.rnn1 = nn.LSTM(
      input_size=conv_op_dim2,
      hidden_size=self.hidden_dim,
      num_layers=1,
      batch_first=True
    )
    self.rnn2 = nn.LSTM(
      input_size=self.hidden_dim,
      hidden_size=embedding_dim,
      num_layers=1,
      batch_first=True
    )
  def forward(self, x):
    x = self.conv(x)
    x = self.conv_1(x)
    x = self.conv_2(x)
    lstm_l1_op, (_, _) = self.rnn1(x)
    lstm_l2_op, (hidden_n, _) = self.rnn2(lstm_l1_op)
    return lstm_l2_op, lstm_l1_op

class Decoder(torch.nn.Module):
  def __init__(self, seq_len, embedding_dim=64, n_features=26):
    super(Decoder, self).__init__()
    self.seq_len, self.embedding_dim = seq_len, embedding_dim
    self.hidden_dim, self.n_features = 2 * embedding_dim, n_features
    self.rnn1 = nn.LSTM(
      input_size=embedding_dim,
      hidden_size=embedding_dim,
      num_layers=1,
      batch_first=True
    )
    self.rnn2 = nn.LSTM(
      input_size=embedding_dim,
      hidden_size=self.hidden_dim,
      num_layers=1,
      batch_first=True
    )
    self.output_layer = nn.Linear(self.hidden_dim * self.seq_len, n_features * self.seq_len)
  def forward(self, x):
    x, (hidden_n, cell_n) = self.rnn1(x)
    x, (hidden_n, cell_n) = self.rnn2(x)
    x = x.contiguous()
    x = x.view(x.shape[0], -1)
    x = self.output_layer(x)
    return x.reshape(x.shape[0],self.seq_len, self.n_features)

class RecurrentAutoencoder(torch.nn.Module):
  def __init__(self, seq_len, n_features, embedding_dim=64, device='cpu'):
    super(RecurrentAutoencoder, self).__init__()
    self.encoder = Encoder(seq_len, n_features, embedding_dim).to(device)
    self.decoder = Decoder(seq_len, embedding_dim, n_features).to(device)
  def forward(self, x):
    x, l1_op = self.encoder(x)
    x = self.decoder(x)
    return x

net = RecurrentAutoencoder(seq_len, input_bins, AE_encoded_dim, device=device)
net.to(device)
# Out:
# RecurrentAutoencoder(
#   (encoder): Encoder(
#     (conv): Conv1d(200, 200, kernel_size=(4,), stride=(1,), groups=200)
#     (conv_1): Conv1d(200, 200, kernel_size=(3,), stride=(1,), groups=200)
#     (conv_2): Conv1d(200, 200, kernel_size=(2,), stride=(1,), groups=200)
#     (rnn1): LSTM(6, 128, batch_first=True)
#     (rnn2): LSTM(128, 64, batch_first=True)
#   )
#   (decoder): Decoder(
#     (rnn1): LSTM(64, 64, batch_first=True)
#     (rnn2): LSTM(64, 128, batch_first=True)
#     (output_layer): Linear(in_features=25600, out_features=2400, bias=True)
#   )
# )

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize(train_loss_graph, test_loss_graph):
  x = range(len(train_loss_graph))
      
  # plot lines
  plt.plot(x, train_loss_graph, label = "Training Loss")
  plt.plot(x, test_loss_graph, label = "Test Loss")
  
  plt.legend()
  plt.show()

def visualize_class_loss(in_loss_graph, we_loss_graph):
  x = range(len(in_loss_graph))
      
  # plot lines
  plt.plot(x, in_loss_graph, label = "Indian Loss")
  plt.plot(x, we_loss_graph, label = "Western Loss")
  
  plt.legend()
  plt.show()

# %%
train_loss_graph = []
test_loss_graph = []
best_loss = np.Inf

indian_loss_graph = []
western_loss_graph = []

for epoch in range(n_epochs):  # loop over the dataset multiple times

    running_loss = 0.0
    total_Loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, inputs)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        total_Loss += loss.item()

        if i % print_every == 0:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / print_every))
            running_loss = 0.0
    
    print('LOSS of the network on the train images after epoch {} is {}'.format(epoch, total_Loss) )
    if reduction_loss == "mean":
      total_Loss = total_Loss/i
      print('Mean of the network on the train images after epoch {} is {}'.format(epoch, total_Loss) )
    
    train_loss_graph.append(total_Loss)
    correct = 0
    total = 0
    running_loss = 0.0
    total_Loss = 0.0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for j, data in enumerate(testloader,0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # calculate outputs by running images through the network
            outputs = net(inputs)
            loss = criterion(outputs, inputs)
            running_loss += loss.item()
            total_Loss += loss.item()

    print('LOSS of the network on the test images: %d %%' % (total_Loss))
    if reduction_loss == "mean":
      total_Loss = total_Loss/j
      print('Mean of the network on the train images after epoch {} is {}'.format(epoch, total_Loss) )
    
    test_loss_graph.append(total_Loss)
    visualize(train_loss_graph, test_loss_graph)
    if total_Loss < best_loss:
      best_loss = total_Loss
      torch.save(net.state_dict(), os.path.join(BASE_PATH, "best_model.pt"))

    running_loss = 0.0
    total_Loss = 0.0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for j, data in enumerate(indian_loader,0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # calculate outputs by running images through the network
            outputs = net(inputs)
            loss = criterion(outputs, inputs)
            running_loss += loss.item()
            total_Loss += loss.item()

    print('LOSS of the network on the test images: %d %%' % (total_Loss))
    if reduction_loss == "mean":
      total_Loss = total_Loss/j
      print('Mean of the network on the train images after epoch {} is {}'.format(epoch, total_Loss) )

    indian_loss_graph.append(total_Loss)

    running_loss = 0.0
    total_Loss = 0.0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for j, data in enumerate(western_loader,0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # calculate outputs by running images through the network
            outputs = net(inputs)
            loss = criterion(outputs, inputs)
            running_loss += loss.item()
            total_Loss += loss.item()

    print('LOSS of the network on the test images: %d %%' % (total_Loss))
    if reduction_loss == "mean":
      total_Loss = total_Loss/j
      print('Mean of the network on the train images after epoch {} is {}'.format(epoch, total_Loss) )

    western_loss_graph.append(total_Loss)

    visualize_class_loss(indian_loss_graph, western_loss_graph)
          

print('Finished Training')
# Out:
# [1,     1] loss: 0.208
# [1,     2] loss: 0.289
# [1,     3] loss: 0.147
# [1,     4] loss: 0.102
# [1,     5] loss: 0.154
# [1,     6] loss: 0.149
# [1,     7] loss: 0.119
# [1,     8] loss: 0.095
# [1,     9] loss: 0.118
# [1,    10] loss: 0.120
# [1,    11] loss: 0.116
# [1,    12] loss: 0.101
# [1,    13] loss: 0.095
# [1,    14] loss: 0.105
# [1,    15] loss: 0.112
# [1,    16] loss: 0.111
# [1,    17] loss: 0.100
# [1,    18] loss: 0.096
# [1,    19] loss: 0.095
# [1,    20] loss: 0.094
# [1,    21] loss: 0.097
# [1,    22] loss: 0.099
# [1,    23] loss: 0.099
# [1,    24] loss: 0.097
# [1,    25] loss: 0.096
# [1,    26] loss: 0.094
# [1,    27] loss: 0.097
# [1,    28] loss: 0.102
# [1,    29] loss: 0.096
# [1,    30] loss: 0.097
# [1,    31] loss: 0.096
# [1,    32] loss: 0.097
# [1,    33] loss: 0.093
# [1,    34] loss: 0.094
# [1,    35] loss: 0.094
# [1,    36] loss: 0.092
# [1,    37] loss: 0.095
# [1,    38] loss: 0.094
# [1,    39] loss: 0.095
# [1,    40] loss: 0.093
# [1,    41] loss: 0.095
# [1,    42] loss: 0.095
# [1,    43] loss: 0.094
# [1,    44] loss: 0.093
# LOSS of the network on the train images after epoch 0 is 4.819660127162933
# Mean of the network on the train images after epoch 0 is 0.11208511923634729
# LOSS of the network on the test images: 1 %
# Mean of the network on the train images after epoch 0 is 0.09992814188202222
# LOSS of the network on the test images: 0 %
# Mean of the network on the train images after epoch 0 is 0.10319595287243526
# LOSS of the network on the test images: 0 %
# Mean of the network on the train images after epoch 0 is 0.10721914387411541
# [2,     1] loss: 0.094
# [2,     2] loss: 0.094
# [2,     3] loss: 0.093
# [2,     4] loss: 0.093
# [2,     5] loss: 0.096
# [2,     6] loss: 0.093
# [2,     7] loss: 0.093
# [2,     8] loss: 0.095
# [2,     9] loss: 0.094
# [2,    10] loss: 0.093
# [2,    11] loss: 0.095
# [2,    12] loss: 0.094
# [2,    13] loss: 0.094
# [2,    14] loss: 0.095
# LOSS of the network on the test images: 1 %
# Mean of the network on the train images after epoch 28 is 0.0661049774951405
# LOSS of the network on the test images: 0 %
# Mean of the network on the train images after epoch 28 is 0.0726448463069068
# LOSS of the network on the test images: 0 %
# Mean of the network on the train images after epoch 28 is 0.06662831207116444
# [30,     1] loss: 0.025
# [30,     2] loss: 0.025
# [30,     3] loss: 0.025
# [30,     4] loss: 0.025
# [30,     5] loss: 0.024
# [30,     6] loss: 0.025
# [30,     7] loss: 0.024
# [30,     8] loss: 0.025
# [30,     9] loss: 0.023
# [30,    10] loss: 0.025
# [30,    11] loss: 0.024
# [30,    12] loss: 0.023
# [30,    13] loss: 0.025
# [30,    14] loss: 0.025
# [30,    15] loss: 0.024
# [30,    16] loss: 0.024
# [30,    17] loss: 0.024
# [30,    18] loss: 0.024
# [30,    19] loss: 0.025
# [30,    20] loss: 0.025
# [30,    21] loss: 0.025
# [30,    22] loss: 0.025
# [30,    23] loss: 0.023
# [30,    24] loss: 0.023
# [30,    25] loss: 0.023
# [30,    26] loss: 0.023
# [30,    27] loss: 0.023
# [30,    28] loss: 0.023
# [30,    29] loss: 0.023
# [30,    30] loss: 0.024
# [30,    31] loss: 0.025
# [30,    32] loss: 0.025
# [30,    33] loss: 0.024
# [30,    34] loss: 0.024
# [30,    35] loss: 0.023
# [30,    36] loss: 0.025
# [30,    37] loss: 0.024
# [30,    38] loss: 0.025
# [30,    39] loss: 0.025
# [30,    40] loss: 0.024
# [30,    41] loss: 0.024
# [30,    42] loss: 0.023
# [30,    43] loss: 0.023
# [30,    44] loss: 0.023
# LOSS of the network on the train images after epoch 29 is 1.0586215872317553
# Mean of the network on the train images after epoch 29 is 0.024619106679808263
# LOSS of the network on the test images: 1 %
# Mean of the network on the train images after epoch 29 is 0.06971574098699623
# LOSS of the network on the test images: 0 %
# Mean of the network on the train images after epoch 29 is 0.07626811414957047
# LOSS of the network on the test images: 0 %
# Mean of the network on the train images after epoch 29 is 0.070562820467684
# Finished Training

# %%
# get some random training images
dataiter = iter(testloader)
images, labels = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        image, labels = image.to(device), labels.to(device)
        output_img = net(image.unsqueeze(dim=0))
        output_img = output_img.squeeze(dim=0)
        ax.pcolormesh(output_img.detach().cpu().permute(1,0)) # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
# get some random training images
outputs=[]
dataiter = iter(testloader)
images, labels = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(1, 5, figsize=(15, 2))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        image, labels = image.to(device), labels.to(device)
        output_img = net(image.unsqueeze(dim=0))
        output_img = output_img.squeeze(dim=0)
        ax.pcolormesh(output_img.detach().cpu().permute(1,0)) # add image
        outputs.append((image.detach().cpu().permute(1,0).flip(0),arthopod_types[label.item()] ))
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

fig, axis = plt.subplots(1, 5, figsize=(15, 2))
for ax , (image, label) in zip(axis.flat, outputs):
    ax.imshow(image, interpolation='nearest', aspect='auto') # add image
    ax.set(title = f"{label}") # add label

# %%
torch.save(net.state_dict(), os.path.join(BASE_PATH, "final_model.pt"))

# %% [markdown]
# Start evaluation - Test model

# %%
model = RecurrentAutoencoder(seq_len, input_bins, AE_encoded_dim, device=device)
model.load_state_dict(torch.load(os.path.join(BASE_PATH, "best_model.pt"), map_location=device))
# Out:
# <All keys matched successfully>

# %%
# get some random training images
outputs=[]
dataiter = iter(testloader)
images, labels = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(1, 5, figsize=(15, 2))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        image, labels = image.to(device), labels.to(device)
        output_img = model(image.unsqueeze(dim=0))
        output_img = output_img.squeeze(dim=0)
        ax.pcolormesh(output_img.detach().cpu().permute(1,0).flip(0)) # add image
        outputs.append((image.detach().cpu().permute(1,0),arthopod_types[label.item()] ))
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

fig, axis = plt.subplots(1, 5, figsize=(15, 2))
for ax , (image, label) in zip(axis.flat, outputs):
    ax.imshow(image, interpolation='nearest', aspect='auto') # add image
    ax.set(title = f"{label}") # add label

# %% [markdown]
# Combined data set recinstruction

# %%
combined_dataset = MEL_Dataset(dataDF,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)
combinedloader = torch.utils.data.DataLoader(combined_dataset, batch_size=batch_size)

# %%
# dataDF
# dataDF.loc[1, 'labels']
# classes
# os.path.join(BASE_PATH, "Activations_64", str(classes[label]))

# %%
for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_64",  str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_128", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "reconstructions", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "originals",  str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

# %%
id = 0
with torch.no_grad():
    for data in combinedloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        output_l2, output_l1 = model.encoder(inputs)
        output = model(inputs)
        output_l2 = output_l2.detach().cpu().numpy()
        output_l1 = output_l1.detach().cpu().numpy()
        output = output.detach().cpu().numpy()
        labels = labels.detach().cpu().numpy()
        
        for  arr64, arr128, arr48, label in zip(output_l2, output_l1, output, labels):
          print(os.path.join(BASE_PATH, "Activations_64", str(classes[label]), str(id) + ".npy"))
          np.save(os.path.join(BASE_PATH, "Activations_64", str(classes[label]), str(id) + ".npy"),np.transpose(arr64, (1,0)))
          np.save(os.path.join(BASE_PATH, "Activations_128", classes[label] ,  str(id) + ".npy" ), np.transpose(arr128, (1,0)))
          np.save(os.path.join(BASE_PATH, "reconstructions", classes[label] ,  str(id) + ".npy"), np.transpose(arr48, (1,0)))
          id = id + 1

# %% [markdown]
# Strict data separation

# %%
for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_64", "test", str(class_))
  #print("removing ", dir)
  for f in os.listdir(dir):
    #print("removing ", os.path.join(dir, f))
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_128", "test", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "reconstructions", "test", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "originals", "test", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))


for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_64", "training", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_128", "training", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "reconstructions", "training", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "originals", "training", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

# %%
id_test = 0
with torch.no_grad():
    for data_test in testloader:
        inputs, labels = data_test
        inputs, labels = inputs.to(device), labels.to(device)
        output_l2, output_l1 = model.encoder(inputs)
        output = model(inputs)
        output_l2 = output_l2.detach().cpu().numpy()
        output_l1 = output_l1.detach().cpu().numpy()
        output = output.detach().cpu().numpy()
        labels = labels.detach().cpu().numpy()
        inputs = inputs.detach().cpu().numpy()
        
        for  orr48, arr64, arr128, arr48, label in zip(inputs, output_l2, output_l1, output, labels):
          print(os.path.join(BASE_PATH, "Activations_64", "test", str(classes[label]), str(id_test) + ".npy"))
          np.save(os.path.join(BASE_PATH, "Activations_64", "test",str(classes[label]), str(id_test) + ".npy"),np.transpose(arr64, (1,0)))
          np.save(os.path.join(BASE_PATH, "Activations_128", "test",classes[label] ,  str(id_test) + ".npy" ), np.transpose(arr128, (1,0)))
          np.save(os.path.join(BASE_PATH, "reconstructions", "test",classes[label] ,  str(id_test) + ".npy"), np.transpose(arr48, (1,0)))
          np.save(os.path.join(BASE_PATH, "originals", "test",classes[label] ,  str(id_test) + ".npy"), np.transpose(orr48, (1,0)))
          id_test = id_test + 1

# %%
id_train = 0
with torch.no_grad():
    for data in trainloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        output_l2, output_l1 = model.encoder(inputs)
        output = model(inputs)
        output_l2 = output_l2.detach().cpu().numpy()
        output_l1 = output_l1.detach().cpu().numpy()
        output = output.detach().cpu().numpy()
        labels = labels.detach().cpu().numpy()
        inputs = inputs.detach().cpu().numpy()
        
        for  orr48, arr64, arr128, arr48, label in zip(inputs, output_l2, output_l1, output, labels):
          print(os.path.join(BASE_PATH, "Activations_64", "training", str(classes[label]), str(id_train) + ".npy"))
          np.save(os.path.join(BASE_PATH, "Activations_64", "training",str(classes[label]), str(id_train) + ".npy"),np.transpose(arr64, (1,0)))
          np.save(os.path.join(BASE_PATH, "Activations_128", "training",classes[label] ,  str(id_train) + ".npy" ), np.transpose(arr128, (1,0)))
          np.save(os.path.join(BASE_PATH, "reconstructions", "training",classes[label] ,  str(id_train) + ".npy"), np.transpose(arr48, (1,0)))
          np.save(os.path.join(BASE_PATH, "originals", "training",classes[label] ,  str(id_train) + ".npy"), np.transpose(orr48, (1,0)))
          id_train = id_train + 1
# Out:
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/0.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/1.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/2.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/3.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/4.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/5.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/6.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/7.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/8.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/9.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/10.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/11.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/12.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/13.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/14.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/15.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/16.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/17.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/18.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/19.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/20.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/21.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/22.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/23.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/24.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/25.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/26.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/27.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/28.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/29.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/30.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/31.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/32.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/33.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/34.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/35.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/36.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/37.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/38.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/39.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/40.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/41.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/42.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/43.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/44.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/45.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/46.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/47.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/48.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/49.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/50.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/51.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/52.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/53.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/54.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/55.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/56.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/57.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/58.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/59.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/60.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/61.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/62.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/63.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/64.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/65.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/66.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/67.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/68.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/69.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/70.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/71.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/72.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/73.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/74.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/75.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/76.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/77.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/78.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/79.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/80.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/81.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/82.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/83.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/84.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/85.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/86.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/87.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/88.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/89.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/90.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/91.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/92.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/93.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/94.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/95.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/96.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/97.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/98.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/99.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/100.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/101.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/102.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/103.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/104.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/105.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/106.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/107.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/108.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/109.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/110.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/111.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/112.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/113.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/114.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/115.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/116.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/117.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/118.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/119.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/120.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/121.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/122.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/123.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/124.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/125.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/126.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/127.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/128.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/129.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/130.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/131.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/132.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/133.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/134.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/135.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/136.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/137.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/138.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/139.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/140.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/141.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/142.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/143.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/144.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/145.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/146.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/147.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/148.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/149.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/150.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/151.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/152.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/153.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/154.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/155.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/156.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/157.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/158.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/159.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/160.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/161.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/162.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/163.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/164.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/165.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/166.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/167.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/168.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/169.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/170.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/171.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/172.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/173.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/174.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/175.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/176.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/177.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/178.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/179.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/180.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/181.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/182.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/183.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/184.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/185.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/186.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/187.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/188.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/189.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/190.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/191.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/192.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/193.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/194.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/195.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/196.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/197.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/198.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/199.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/200.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/201.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/202.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/203.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/204.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/205.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/206.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/207.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/208.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/209.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/210.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/211.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/212.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/213.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/214.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/215.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/216.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/217.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/218.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/219.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/220.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/221.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/222.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/223.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/224.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/225.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/226.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/227.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/228.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/229.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/230.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/231.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/232.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/233.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/234.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/235.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/236.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/237.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/238.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/239.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/240.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/241.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/242.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/243.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/244.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/245.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/246.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/247.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/248.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/249.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/250.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/251.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/252.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/253.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/254.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/255.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy