# %% [markdown]
# <a href="https://colab.research.google.com/github/agarr3/vajra-new/blob/main/WI_CLASSIFIER_V1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from tqdm import tqdm_notebook as tqdm
from sklearn.preprocessing import LabelEncoder
from PIL import Image
import matplotlib.pyplot as plt
import torch
# Neural networks can be constructed using the torch.nn package.
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset
import torchvision
import torchvision.transforms as transforms

import IPython.display as ipd

import random

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Assuming that we are on a CUDA machine, this should print a CUDA device:

print(device)

#settings
batch_size = 128
validation_split = .3
shuffle_dataset = True
random_seed= 42

criterion = nn.CrossEntropyLoss()

n_epochs = 30
print_every = 1

BASE_PATH = "/content/gdrive/My Drive/vajra/WI_CLASSIFIER_v2/"

input_bins = 48
seq_len=200
# Out:
# cuda:0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# DATA_BASE_PATH = "/content/gdrive/"
# DATA_SONG_DIR = "My Drive"
# DATA_IMG_DIR = "My Drive"

# files = []
# exclusion = ["098567.npy","098569.npy", '098565.npy']
# for r,d, fileList in os.walk("/content/gdrive/My Drive/Western_numpy"):
#   for file in fileList:
#     if(file not in exclusion):
#       files.append([file,file, "Western_numpy"])
#     else:
#       print(file)

# random.seed(1234)
# files = random.sample(files, 2008)

# for r,d, fileList in os.walk("/content/gdrive/My Drive/Indian_numpy"):
#   for file in fileList:
#     if(True):
#       files.append([file,file, "Indian_numpy"])
#     else:
#       print(file)

# data = pd.DataFrame(files, columns=['Images','songs','labels'])
# #data = data.sample(frac=1).reset_index(drop=True)

# print(len(data.index))
# data.head()

DATA_BASE_PATH = "/content/gdrive/My Drive/vajra/songs-vajra-data/MEL/"
DATA_SONG_DIR = "48Bins"
DATA_IMG_DIR = "48Bins"

files = []
exclusion = ["098567.npy","098569.npy", '098565.npy']
for r,d, fileList in os.walk("/content/gdrive/My Drive/vajra/songs-vajra-data/MEL/48Bins/Western_mel_numpy"):
  for file in fileList:
    if(file not in exclusion):
      files.append([file,file, "Western_mel_numpy"])
    else:
      print(file)

random.seed(1234)
files = random.sample(files, 2008)

for r,d, fileList in os.walk("/content/gdrive/My Drive/vajra/songs-vajra-data/MEL/48Bins/Indian_mel_numpy"):
  for file in fileList:
    if(True):
      files.append([file,file, "Indian_mel_numpy"])
    else:
      print(file)

data = pd.DataFrame(files, columns=['Images','songs','labels'])
data.head()
# Out:
#        Images       songs             labels
# 0  039357.npy  039357.npy  Western_mel_numpy
# 1  107591.npy  107591.npy  Western_mel_numpy
# 2  143217.npy  143217.npy  Western_mel_numpy
# 3  140623.npy  140623.npy  Western_mel_numpy
# 4  147059.npy  147059.npy  Western_mel_numpy

# %%
data.groupby("labels").count()
# Out:
#                    Images  songs
# labels
# Indian_mel_numpy     2008   2008
# Western_mel_numpy    2008   2008

# %%
test_idx = random. randint(0,1000)
test_img_path = os.path.join(DATA_BASE_PATH, DATA_IMG_DIR, data.loc[test_idx, 'labels'], data.loc[test_idx, 'Images'])
print(test_img_path)

numpy_arr = np.load(test_img_path)

array = numpy_arr*-1
print(array.max())
array *= (255.0/array.max())
array = 255 - array

test_image = Image.fromarray(array)
test_image = test_image.convert('L')
test_image = test_image.resize((300,300))
test_image
# Out:
# /content/gdrive/My Drive/vajra/songs-vajra-data/MEL/48Bins/Western_mel_numpy/122646.npy
# 80.0
# <PIL.Image.Image image mode=L size=300x300 at 0x7FF4C84A4A50>

# %%
test_img_path = '/content/gdrive/My Drive/Kaggle/GTZAN/Data/images_original/reggae/reggae00016.png'
test_image = Image.open(test_img_path)
test_image = test_image.convert('RGB').convert('L')
test_image
# Out:
# <PIL.Image.Image image mode=L size=432x288 at 0x7FF4C056C0D0>

# %%
lb = LabelEncoder()
data['encoded_labels'] = lb.fit_transform(data['labels'])
data.head()
# Out:
#        Images       songs             labels  encoded_labels
# 0  039357.npy  039357.npy  Western_mel_numpy               1
# 1  107591.npy  107591.npy  Western_mel_numpy               1
# 2  143217.npy  143217.npy  Western_mel_numpy               1
# 3  140623.npy  140623.npy  Western_mel_numpy               1
# 4  147059.npy  147059.npy  Western_mel_numpy               1

# %%
classes = ('Indian_numpy', 'Western_numpy')
data.groupby(by=['labels','encoded_labels']).count()
# Out:
#                                   Images  songs
# labels            encoded_labels
# Indian_mel_numpy  0                 2008   2008
# Western_mel_numpy 1                 2008   2008

# %%
from sklearn.model_selection import train_test_split

data = data.sample(frac=1)
df_train, df_test = train_test_split(data, test_size=validation_split, stratify=data[["labels"]])

df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
df_train.groupby(by=['labels','encoded_labels']).count()
# Out:
#                                   Images  songs
# labels            encoded_labels
# Indian_mel_numpy  0                 1406   1406
# Western_mel_numpy 1                 1405   1405

# %%
df_test.groupby(by=['labels','encoded_labels']).count()
# Out:
#                                   Images  songs
# labels            encoded_labels
# Indian_mel_numpy  0                  602    602
# Western_mel_numpy 1                  603    603

# %%
transform_normal = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

transform = transforms.Compose(
    [transforms.ToTensor()])

# %%
class MEL_Dataset(Dataset):
    def __init__(self, img_data,img_path,transform=None):
        self.img_path = img_path
        self.transform = transform
        self.img_data = img_data
        
    def __len__(self):
        return len(self.img_data)
    
    def __getitem__(self, index):
        img_name = os.path.join(self.img_path,self.img_data.loc[index, 'labels'],
                                self.img_data.loc[index, 'Images'])
        image = np.load(img_name)
        image = image[:,:seq_len]
        label = torch.tensor(self.img_data.loc[index, 'encoded_labels'])
        if self.transform is not None:
            image = self.transform(image)
        return image, label

# %%
train_dataset = MEL_Dataset(df_train,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)
test_dataset = MEL_Dataset(df_test,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)

# %%
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size)
testloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size)

# %%
def img_display(img):
    #img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    npimg = np.transpose(npimg, (1, 2, 0))
    return npimg.squeeze()

def mel_display(S_DB):
    #print(S_DB.shape)
    S_DB = S_DB.numpy()
    array = S_DB*-1
    #print(array.max())
    array *= (255.0/array.max())
    array = 255 - array

    array = np.transpose(array, (1, 2, 0))
    return array.squeeze()

def imshow(img):
    #img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    array = npimg*-1
    #print(array.max())
    array *= (255.0/array.max())
    array = 255 - array
    array = np.transpose(array, (1, 2, 0))
    plt.imshow(array.squeeze(), interpolation='nearest', aspect='auto')
    plt.show()

# %%
# get some random training images
dataiter = iter(trainloader)
images, labels = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        ax.imshow(mel_display(image), interpolation='nearest', aspect='auto') # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
# get some random training images
dataiter = iter(testloader)
images, labels = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        ax.imshow(mel_display(image), interpolation='nearest', aspect='auto') # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(1, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(6768, 120)
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 2)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = torch.flatten(x, 1) # flatten all dimensions except batch
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#   (fc1): Linear(in_features=6768, out_features=120, bias=True)
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (fc3): Linear(in_features=84, out_features=2, bias=True)
# )

# %%
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
for epoch in range(n_epochs):  # loop over the dataset multiple times

    running_loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

        if i % print_every == 0:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / print_every))
            running_loss = 0.0
    
    print('Accuracy of the network on the train images after epoch {} is {}'.format(epoch, 100 * correct / total) )
    correct = 0
    total = 0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for data in testloader:
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            # calculate outputs by running images through the network
            outputs = net(inputs)
            # the class with the highest energy is what we choose as prediction
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    print('Accuracy of the network on the test images: %d %%' % (
        100 * correct / total))
        
        
    

print('Finished Training')
# Out:
# [1,     1] loss: 0.688
# [1,     2] loss: 0.726
# [1,     3] loss: 0.703
# [1,     4] loss: 0.670
# [1,     5] loss: 0.686
# [1,     6] loss: 0.687
# [1,     7] loss: 0.669
# [1,     8] loss: 0.692
# [1,     9] loss: 0.879
# [1,    10] loss: 0.729
# [1,    11] loss: 0.683
# [1,    12] loss: 0.680
# [1,    13] loss: 0.694
# [1,    14] loss: 0.662
# [1,    15] loss: 0.662
# [1,    16] loss: 0.651
# [1,    17] loss: 0.705
# [1,    18] loss: 0.692
# [1,    19] loss: 0.673
# [1,    20] loss: 0.675
# [1,    21] loss: 0.672
# [1,    22] loss: 0.642
# Accuracy of the network on the train images after epoch 0 is 54.3934542867307
# Accuracy of the network on the test images: 63 %
# [2,     1] loss: 0.658
# [2,     2] loss: 0.641
# [2,     3] loss: 0.655
# [2,     4] loss: 0.656
# [2,     5] loss: 0.654
# [2,     6] loss: 0.660
# [2,     7] loss: 0.624
# [2,     8] loss: 0.677
# [2,     9] loss: 0.619
# [2,    10] loss: 0.616
# [2,    11] loss: 0.606
# [2,    12] loss: 0.617
# [2,    13] loss: 0.609
# [2,    14] loss: 0.626
# [2,    15] loss: 0.584
# [2,    16] loss: 0.612
# [2,    17] loss: 0.619
# [2,    18] loss: 0.700
# [2,    19] loss: 0.612
# [2,    20] loss: 0.731
# [2,    21] loss: 0.631
# [2,    22] loss: 0.581
# Accuracy of the network on the train images after epoch 1 is 63.64283173247954
# Accuracy of the network on the test images: 58 %
# [3,     1] loss: 0.709
# [3,     2] loss: 0.596
# [3,     3] loss: 0.707
# [3,     4] loss: 0.636
# [3,     5] loss: 0.648
# [3,     6] loss: 0.633
# [3,     7] loss: 0.590
# [3,     8] loss: 0.598
# [3,     9] loss: 0.637
# [3,    10] loss: 0.585
# [3,    11] loss: 0.554
# [3,    12] loss: 0.598
# [3,    13] loss: 0.582
# [3,    14] loss: 0.616
# [3,    15] loss: 0.573
# [3,    16] loss: 0.595
# [3,    17] loss: 0.592
# [3,    18] loss: 0.654
# [3,    19] loss: 0.601
# [3,    20] loss: 0.695
# [3,    21] loss: 0.625
# [3,    22] loss: 0.531
# Accuracy of the network on the train images after epoch 2 is 65.42155816435432
# Accuracy of the network on the test images: 63 %
# [4,     1] loss: 0.681
# [4,     2] loss: 0.576
# [4,     3] loss: 0.615
# [4,     4] loss: 0.632
# [4,     5] loss: 0.595
# [4,     6] loss: 0.605
# [4,     7] loss: 0.578
# [4,     8] loss: 0.596
# [4,     9] loss: 0.572
# [4,    10] loss: 0.560
# [4,    11] loss: 0.513
# [4,    12] loss: 0.551
# [4,    13] loss: 0.558
# [4,    14] loss: 0.594
# [4,    15] loss: 0.533
# [4,    16] loss: 0.573
# [4,    17] loss: 0.571
# [4,    18] loss: 0.616
# [4,    19] loss: 0.549
# [4,    20] loss: 0.767
# [4,    21] loss: 0.542
# [4,    22] loss: 0.563
# Accuracy of the network on the train images after epoch 3 is 69.79722518676627
# Accuracy of the network on the test images: 67 %
# [5,     1] loss: 0.634
# [5,     2] loss: 0.598
# [5,     3] loss: 0.665
# [5,     4] loss: 0.621
# [5,     5] loss: 0.650
# [5,     6] loss: 0.603
# [5,     7] loss: 0.549
# [5,     8] loss: 0.565
# [5,     9] loss: 0.602
# [5,    10] loss: 0.559
# [5,    11] loss: 0.534
# [5,    12] loss: 0.563
# [5,    13] loss: 0.550
# [5,    14] loss: 0.614
# [5,    15] loss: 0.536
# [5,    16] loss: 0.565
# [5,    17] loss: 0.573
# [5,    18] loss: 0.592
# [5,    19] loss: 0.558
# [5,    20] loss: 0.699
# [5,    21] loss: 0.568
# [5,    22] loss: 0.493
# Accuracy of the network on the train images after epoch 4 is 68.44539309854144
# Accuracy of the network on the test images: 67 %
# [6,     1] loss: 0.646
# [6,     2] loss: 0.523
# [6,     3] loss: 0.604
# [6,     4] loss: 0.600
# [6,     5] loss: 0.558
# [6,     6] loss: 0.580
# [6,     7] loss: 0.525
# [6,     8] loss: 0.533
# [6,     9] loss: 0.562
# [6,    10] loss: 0.531
# [6,    11] loss: 0.473
# [6,    12] loss: 0.525
# [6,    13] loss: 0.524
# [6,    14] loss: 0.593
# [6,    15] loss: 0.500
# [6,    16] loss: 0.546
# [6,    17] loss: 0.553
# [6,    18] loss: 0.531
# [6,    19] loss: 0.521
# [6,    20] loss: 0.727
# [6,    21] loss: 0.521
# [6,    22] loss: 0.517
# Accuracy of the network on the train images after epoch 5 is 72.32301672002846
# Accuracy of the network on the test images: 72 %
# [7,     1] loss: 0.583
# [7,     2] loss: 0.593
# [7,     3] loss: 0.606
# [7,     4] loss: 0.635
# [7,     5] loss: 0.615
# [7,     6] loss: 0.574
# [7,     7] loss: 0.521
# [7,     8] loss: 0.540
# [7,     9] loss: 0.558
# [7,    10] loss: 0.546
# [7,    11] loss: 0.515
# [7,    12] loss: 0.539
# [7,    13] loss: 0.524
# [7,    14] loss: 0.614
# [7,    15] loss: 0.513
# [7,    16] loss: 0.545
# [7,    17] loss: 0.559
# [7,    18] loss: 0.566
# [7,    19] loss: 0.538
# [7,    20] loss: 0.698
# [7,    21] loss: 0.547
# [7,    22] loss: 0.468
# Accuracy of the network on the train images after epoch 6 is 71.07790821771611
# Accuracy of the network on the test images: 68 %
# [8,     1] loss: 0.637
# [8,     2] loss: 0.504
# [8,     3] loss: 0.566
# [8,     4] loss: 0.581
# [8,     5] loss: 0.523
# [8,     6] loss: 0.559
# [8,     7] loss: 0.492
# [8,     8] loss: 0.519
# [8,     9] loss: 0.513
# [8,    10] loss: 0.509
# [8,    11] loss: 0.442
# [8,    12] loss: 0.497
# [8,    13] loss: 0.504
# [8,    14] loss: 0.570
# [8,    15] loss: 0.500
# [8,    16] loss: 0.528
# [8,    17] loss: 0.537
# [8,    18] loss: 0.540
# [8,    19] loss: 0.518
# [8,    20] loss: 0.729
# [8,    21] loss: 0.509
# [8,    22] loss: 0.474
# Accuracy of the network on the train images after epoch 7 is 74.20846673781573
# Accuracy of the network on the test images: 70 %
# [9,     1] loss: 0.616
# [9,     2] loss: 0.491
# [9,     3] loss: 0.599
# [9,     4] loss: 0.564
# [9,     5] loss: 0.526
# [9,     6] loss: 0.558
# [9,     7] loss: 0.474
# [9,     8] loss: 0.497
# [9,     9] loss: 0.538
# [9,    10] loss: 0.501
# [9,    11] loss: 0.448
# [9,    12] loss: 0.491
# [9,    13] loss: 0.494
# [9,    14] loss: 0.578
# [9,    15] loss: 0.492
# [9,    16] loss: 0.515
# [9,    17] loss: 0.529
# [9,    18] loss: 0.516
# [9,    19] loss: 0.503
# [9,    20] loss: 0.711
# [9,    21] loss: 0.494
# [9,    22] loss: 0.462
# Accuracy of the network on the train images after epoch 8 is 74.52863749555318
# Accuracy of the network on the test images: 71 %
# [10,     1] loss: 0.603
# [10,     2] loss: 0.473
# [10,     3] loss: 0.574
# [10,     4] loss: 0.547
# [10,     5] loss: 0.496
# [10,     6] loss: 0.542
# [10,     7] loss: 0.463
# [10,     8] loss: 0.481
# [10,     9] loss: 0.515
# [10,    10] loss: 0.486
# [10,    11] loss: 0.423
# [10,    12] loss: 0.470
# [10,    13] loss: 0.481
# [10,    14] loss: 0.566
# [10,    15] loss: 0.483
# [10,    16] loss: 0.501
# [10,    17] loss: 0.520
# [10,    18] loss: 0.492
# [10,    19] loss: 0.488
# [10,    20] loss: 0.697
# [10,    21] loss: 0.487
# [10,    22] loss: 0.456
# Accuracy of the network on the train images after epoch 9 is 76.27178939879046
# Accuracy of the network on the test images: 72 %
# [11,     1] loss: 0.594
# [11,     2] loss: 0.475
# [11,     3] loss: 0.572
# [11,     4] loss: 0.540
# [11,     5] loss: 0.488
# [11,     6] loss: 0.542
# [11,     7] loss: 0.449
# [11,     8] loss: 0.471
# [11,     9] loss: 0.523
# [11,    10] loss: 0.471
# [11,    11] loss: 0.416
# [11,    12] loss: 0.461
# [11,    13] loss: 0.478
# [11,    14] loss: 0.563
# [11,    15] loss: 0.483
# [11,    16] loss: 0.495
# [11,    17] loss: 0.508
# [11,    18] loss: 0.482
# [11,    19] loss: 0.478
# [11,    20] loss: 0.686
# [11,    21] loss: 0.475
# [11,    22] loss: 0.442
# Accuracy of the network on the train images after epoch 10 is 76.8054073283529
# Accuracy of the network on the test images: 72 %
# [12,     1] loss: 0.563
# [12,     2] loss: 0.461
# [12,     3] loss: 0.548
# [12,     4] loss: 0.519
# [12,     5] loss: 0.471
# [12,     6] loss: 0.530
# [12,     7] loss: 0.435
# [12,     8] loss: 0.459
# [12,     9] loss: 0.495
# [12,    10] loss: 0.461
# [12,    11] loss: 0.397
# [12,    12] loss: 0.439
# [12,    13] loss: 0.470
# [12,    14] loss: 0.552
# [12,    15] loss: 0.474
# [12,    16] loss: 0.484
# [12,    17] loss: 0.493
# [12,    18] loss: 0.454
# [12,    19] loss: 0.460
# [12,    20] loss: 0.652
# [12,    21] loss: 0.459
# [12,    22] loss: 0.445
# Accuracy of the network on the train images after epoch 11 is 77.73034507292779
# Accuracy of the network on the test images: 74 %
# [13,     1] loss: 0.520
# [13,     2] loss: 0.457
# [13,     3] loss: 0.531
# [13,     4] loss: 0.510
# [13,     5] loss: 0.464
# [13,     6] loss: 0.515
# [13,     7] loss: 0.418
# [13,     8] loss: 0.445
# [13,     9] loss: 0.488
# [13,    10] loss: 0.457
# [13,    11] loss: 0.394
# [13,    12] loss: 0.422
# [13,    13] loss: 0.464
# [13,    14] loss: 0.536
# [13,    15] loss: 0.459
# [13,    16] loss: 0.478
# [13,    17] loss: 0.465
# [13,    18] loss: 0.423
# [13,    19] loss: 0.448
# [13,    20] loss: 0.606
# [13,    21] loss: 0.450
# [13,    22] loss: 0.429
# Accuracy of the network on the train images after epoch 12 is 79.11775168979011
# Accuracy of the network on the test images: 74 %
# [14,     1] loss: 0.481
# [14,     2] loss: 0.470
# [14,     3] loss: 0.492
# [14,     4] loss: 0.522
# [14,     5] loss: 0.457
# [14,     6] loss: 0.502
# [14,     7] loss: 0.424
# [14,     8] loss: 0.434
# [14,     9] loss: 0.439
# [14,    10] loss: 0.456
# [14,    11] loss: 0.372
# [14,    12] loss: 0.403
# [14,    13] loss: 0.452
# [14,    14] loss: 0.519
# [14,    15] loss: 0.452
# [14,    16] loss: 0.475
# [14,    17] loss: 0.449
# [14,    18] loss: 0.423
# [14,    19] loss: 0.424
# [14,    20] loss: 0.597
# [14,    21] loss: 0.437
# [14,    22] loss: 0.435
# Accuracy of the network on the train images after epoch 13 is 78.93987904660263
# Accuracy of the network on the test images: 75 %
# [15,     1] loss: 0.457
# [15,     2] loss: 0.483
# [15,     3] loss: 0.466
# [15,     4] loss: 0.526
# [15,     5] loss: 0.437
# [15,     6] loss: 0.492
# [15,     7] loss: 0.425
# [15,     8] loss: 0.424
# [15,     9] loss: 0.413
# [15,    10] loss: 0.454
# [15,    11] loss: 0.365
# [15,    12] loss: 0.401
# [15,    13] loss: 0.439
# [15,    14] loss: 0.505
# [15,    15] loss: 0.451
# [15,    16] loss: 0.465
# [15,    17] loss: 0.431
# [15,    18] loss: 0.426
# [15,    19] loss: 0.405
# [15,    20] loss: 0.597
# [15,    21] loss: 0.421
# [15,    22] loss: 0.445
# Accuracy of the network on the train images after epoch 14 is 79.08217716115261
# Accuracy of the network on the test images: 75 %
# [16,     1] loss: 0.438
# [16,     2] loss: 0.456
# [16,     3] loss: 0.463
# [16,     4] loss: 0.482
# [16,     5] loss: 0.431
# [16,     6] loss: 0.475
# [16,     7] loss: 0.392
# [16,     8] loss: 0.408
# [16,     9] loss: 0.404
# [16,    10] loss: 0.438
# [16,    11] loss: 0.351
# [16,    12] loss: 0.378
# [16,    13] loss: 0.421
# [16,    14] loss: 0.491
# [16,    15] loss: 0.435
# [16,    16] loss: 0.446
# [16,    17] loss: 0.408
# [16,    18] loss: 0.394
# [16,    19] loss: 0.384
# [16,    20] loss: 0.539
# [16,    21] loss: 0.397
# [16,    22] loss: 0.406
# Accuracy of the network on the train images after epoch 15 is 80.75418000711491
# Accuracy of the network on the test images: 75 %
# [17,     1] loss: 0.407
# [17,     2] loss: 0.448
# [17,     3] loss: 0.428
# [17,     4] loss: 0.484
# [17,     5] loss: 0.398
# [17,     6] loss: 0.454
# [17,     7] loss: 0.377
# [17,     8] loss: 0.403
# [17,     9] loss: 0.371
# [17,    10] loss: 0.394
# [17,    11] loss: 0.349
# [17,    12] loss: 0.359
# [17,    13] loss: 0.429
# [17,    14] loss: 0.474
# [17,    15] loss: 0.478
# [17,    16] loss: 0.431
# [17,    17] loss: 0.429
# [17,    18] loss: 0.392
# [17,    19] loss: 0.376
# [17,    20] loss: 0.529
# [17,    21] loss: 0.384
# [17,    22] loss: 0.426
# Accuracy of the network on the train images after epoch 16 is 80.89647812166488
# Accuracy of the network on the test images: 75 %
# [18,     1] loss: 0.394
# [18,     2] loss: 0.441
# [18,     3] loss: 0.425
# [18,     4] loss: 0.444
# [18,     5] loss: 0.393
# [18,     6] loss: 0.434
# [18,     7] loss: 0.362
# [18,     8] loss: 0.368
# [18,     9] loss: 0.355
# [18,    10] loss: 0.411
# [18,    11] loss: 0.318
# [18,    12] loss: 0.353
# [18,    13] loss: 0.376
# [18,    14] loss: 0.462
# [18,    15] loss: 0.410
# [18,    16] loss: 0.422
# [18,    17] loss: 0.377
# [18,    18] loss: 0.373
# [18,    19] loss: 0.344
# [18,    20] loss: 0.498
# [18,    21] loss: 0.342
# [18,    22] loss: 0.396
# Accuracy of the network on the train images after epoch 17 is 82.71077908217715
# Accuracy of the network on the test images: 75 %
# [19,     1] loss: 0.366
# [19,     2] loss: 0.398
# [19,     3] loss: 0.394
# [19,     4] loss: 0.415
# [19,     5] loss: 0.363
# [19,     6] loss: 0.400
# [19,     7] loss: 0.333
# [19,     8] loss: 0.360
# [19,     9] loss: 0.322
# [19,    10] loss: 0.358
# [19,    11] loss: 0.308
# [19,    12] loss: 0.325
# [19,    13] loss: 0.370
# [19,    14] loss: 0.437
# [19,    15] loss: 0.453
# [19,    16] loss: 0.395
# [19,    17] loss: 0.393
# [19,    18] loss: 0.330
# [19,    19] loss: 0.340
# [19,    20] loss: 0.408
# [19,    21] loss: 0.333
# [19,    22] loss: 0.343
# Accuracy of the network on the train images after epoch 18 is 84.13376022767699
# Accuracy of the network on the test images: 76 %
# [20,     1] loss: 0.337
# [20,     2] loss: 0.377
# [20,     3] loss: 0.368
# [20,     4] loss: 0.400
# [20,     5] loss: 0.342
# [20,     6] loss: 0.370
# [20,     7] loss: 0.285
# [20,     8] loss: 0.352
# [20,     9] loss: 0.300
# [20,    10] loss: 0.329
# [20,    11] loss: 0.279
# [20,    12] loss: 0.298
# [20,    13] loss: 0.328
# [20,    14] loss: 0.404
# [20,    15] loss: 0.401
# [20,    16] loss: 0.370
# [20,    17] loss: 0.349
# [20,    18] loss: 0.288
# [20,    19] loss: 0.303
# [20,    20] loss: 0.345
# [20,    21] loss: 0.289
# [20,    22] loss: 0.294
# Accuracy of the network on the train images after epoch 19 is 86.23265741728922
# Accuracy of the network on the test images: 76 %
# [21,     1] loss: 0.308
# [21,     2] loss: 0.320
# [21,     3] loss: 0.346
# [21,     4] loss: 0.335
# [21,     5] loss: 0.333
# [21,     6] loss: 0.338
# [21,     7] loss: 0.262
# [21,     8] loss: 0.302
# [21,     9] loss: 0.279
# [21,    10] loss: 0.366
# [21,    11] loss: 0.316
# [21,    12] loss: 0.279
# [21,    13] loss: 0.342
# [21,    14] loss: 0.402
# [21,    15] loss: 0.372
# [21,    16] loss: 0.384
# [21,    17] loss: 0.313
# [21,    18] loss: 0.273
# [21,    19] loss: 0.272
# [21,    20] loss: 0.325
# [21,    21] loss: 0.271
# [21,    22] loss: 0.283
# Accuracy of the network on the train images after epoch 20 is 86.80184987548915
# Accuracy of the network on the test images: 77 %
# [22,     1] loss: 0.286
# [22,     2] loss: 0.306
# [22,     3] loss: 0.317
# [22,     4] loss: 0.313
# [22,     5] loss: 0.307
# [22,     6] loss: 0.296
# [22,     7] loss: 0.237
# [22,     8] loss: 0.278
# [22,     9] loss: 0.259
# [22,    10] loss: 0.350
# [22,    11] loss: 0.324
# [22,    12] loss: 0.266
# [22,    13] loss: 0.303
# [22,    14] loss: 0.376
# [22,    15] loss: 0.332
# [22,    16] loss: 0.351
# [22,    17] loss: 0.283
# [22,    18] loss: 0.247
# [22,    19] loss: 0.252
# [22,    20] loss: 0.301
# [22,    21] loss: 0.242
# [22,    22] loss: 0.274
# Accuracy of the network on the train images after epoch 21 is 88.04695837780149
# Accuracy of the network on the test images: 77 %
# [23,     1] loss: 0.251
# [23,     2] loss: 0.291
# [23,     3] loss: 0.298
# [23,     4] loss: 0.284
# [23,     5] loss: 0.282
# [23,     6] loss: 0.266
# [23,     7] loss: 0.214
# [23,     8] loss: 0.253
# [23,     9] loss: 0.224
# [23,    10] loss: 0.305
# [23,    11] loss: 0.272
# [23,    12] loss: 0.238
# [23,    13] loss: 0.305
# [23,    14] loss: 0.335
# [23,    15] loss: 0.331
# [23,    16] loss: 0.350
# [23,    17] loss: 0.257
# [23,    18] loss: 0.249
# [23,    19] loss: 0.254
# [23,    20] loss: 0.281
# [23,    21] loss: 0.281
# [23,    22] loss: 0.304
# Accuracy of the network on the train images after epoch 22 is 88.68729989327642
# Accuracy of the network on the test images: 77 %
# [24,     1] loss: 0.239
# [24,     2] loss: 0.344
# [24,     3] loss: 0.272
# [24,     4] loss: 0.300
# [24,     5] loss: 0.245
# [24,     6] loss: 0.258
# [24,     7] loss: 0.201
# [24,     8] loss: 0.275
# [24,     9] loss: 0.248
# [24,    10] loss: 0.244
# [24,    11] loss: 0.215
# [24,    12] loss: 0.318
# [24,    13] loss: 0.237
# [24,    14] loss: 0.403
# [24,    15] loss: 0.655
# [24,    16] loss: 0.260
# [24,    17] loss: 0.537
# [24,    18] loss: 0.338
# [24,    19] loss: 0.329
# [24,    20] loss: 0.534
# [24,    21] loss: 0.327
# [24,    22] loss: 0.405
# Accuracy of the network on the train images after epoch 23 is 86.4461045891142
# Accuracy of the network on the test images: 66 %
# [25,     1] loss: 0.443
# [25,     2] loss: 0.367
# [25,     3] loss: 0.353
# [25,     4] loss: 0.396
# [25,     5] loss: 0.298
# [25,     6] loss: 0.387
# [25,     7] loss: 0.315
# [25,     8] loss: 0.307
# [25,     9] loss: 0.256
# [25,    10] loss: 0.347
# [25,    11] loss: 0.223
# [25,    12] loss: 0.349
# [25,    13] loss: 0.327
# [25,    14] loss: 0.435
# [25,    15] loss: 0.296
# [25,    16] loss: 0.499
# [25,    17] loss: 0.231
# [25,    18] loss: 0.414
# [25,    19] loss: 0.311
# [25,    20] loss: 0.337
# [25,    21] loss: 0.360
# [25,    22] loss: 0.266
# Accuracy of the network on the train images after epoch 24 is 84.8808253290644
# Accuracy of the network on the test images: 66 %
# [26,     1] loss: 0.436
# [26,     2] loss: 0.347
# [26,     3] loss: 0.406
# [26,     4] loss: 0.275
# [26,     5] loss: 0.252
# [26,     6] loss: 0.282
# [26,     7] loss: 0.311
# [26,     8] loss: 0.306
# [26,     9] loss: 0.260
# [26,    10] loss: 0.361
# [26,    11] loss: 0.254
# [26,    12] loss: 0.297
# [26,    13] loss: 0.306
# [26,    14] loss: 0.322
# [26,    15] loss: 0.320
# [26,    16] loss: 0.346
# [26,    17] loss: 0.236
# [26,    18] loss: 0.307
# [26,    19] loss: 0.263
# [26,    20] loss: 0.383
# [26,    21] loss: 0.190
# [26,    22] loss: 0.247
# Accuracy of the network on the train images after epoch 25 is 87.40661686232657
# Accuracy of the network on the test images: 76 %
# [27,     1] loss: 0.216
# [27,     2] loss: 0.229
# [27,     3] loss: 0.254
# [27,     4] loss: 0.224
# [27,     5] loss: 0.191
# [27,     6] loss: 0.214
# [27,     7] loss: 0.180
# [27,     8] loss: 0.204
# [27,     9] loss: 0.184
# [27,    10] loss: 0.239
# [27,    11] loss: 0.171
# [27,    12] loss: 0.239
# [27,    13] loss: 0.194
# [27,    14] loss: 0.303
# [27,    15] loss: 0.324
# [27,    16] loss: 0.271
# [27,    17] loss: 0.221
# [27,    18] loss: 0.209
# [27,    19] loss: 0.276
# [27,    20] loss: 0.200
# [27,    21] loss: 0.187
# [27,    22] loss: 0.176
# Accuracy of the network on the train images after epoch 26 is 91.60441124155105
# Accuracy of the network on the test images: 73 %
# [28,     1] loss: 0.361
# [28,     2] loss: 0.195
# [28,     3] loss: 0.322
# [28,     4] loss: 0.208
# [28,     5] loss: 0.294
# [28,     6] loss: 0.334
# [28,     7] loss: 0.254
# [28,     8] loss: 0.244
# [28,     9] loss: 0.170
# [28,    10] loss: 0.361
# [28,    11] loss: 0.236
# [28,    12] loss: 0.330
# [28,    13] loss: 0.330
# [28,    14] loss: 0.317
# [28,    15] loss: 0.361
# [28,    16] loss: 0.328
# [28,    17] loss: 0.242
# [28,    18] loss: 0.400
# [28,    19] loss: 0.367
# [28,    20] loss: 0.417
# [28,    21] loss: 0.383
# [28,    22] loss: 0.330
# Accuracy of the network on the train images after epoch 27 is 86.16150836001422
# Accuracy of the network on the test images: 71 %
# [29,     1] loss: 0.282
# [29,     2] loss: 0.244
# [29,     3] loss: 0.316
# [29,     4] loss: 0.246
# [29,     5] loss: 0.309
# [29,     6] loss: 0.283
# [29,     7] loss: 0.512
# [29,     8] loss: 0.234
# [29,     9] loss: 0.233
# [29,    10] loss: 0.237
# [29,    11] loss: 0.204
# [29,    12] loss: 0.261
# [29,    13] loss: 0.278
# [29,    14] loss: 0.289
# [29,    15] loss: 0.358
# [29,    16] loss: 0.247
# [29,    17] loss: 0.264
# [29,    18] loss: 0.253
# [29,    19] loss: 0.337
# [29,    20] loss: 0.324
# [29,    21] loss: 0.279
# [29,    22] loss: 0.481
# Accuracy of the network on the train images after epoch 28 is 87.37104233368908
# Accuracy of the network on the test images: 73 %
# [30,     1] loss: 0.197
# [30,     2] loss: 0.590
# [30,     3] loss: 0.437
# [30,     4] loss: 0.254
# [30,     5] loss: 0.397
# [30,     6] loss: 0.374
# [30,     7] loss: 0.240
# [30,     8] loss: 0.269
# [30,     9] loss: 0.224
# [30,    10] loss: 0.317
# [30,    11] loss: 0.276
# [30,    12] loss: 0.310
# [30,    13] loss: 0.374
# [30,    14] loss: 0.381
# [30,    15] loss: 0.423
# [30,    16] loss: 0.335
# [30,    17] loss: 0.274
# [30,    18] loss: 0.282
# [30,    19] loss: 0.272
# [30,    20] loss: 0.241
# [30,    21] loss: 0.237
# [30,    22] loss: 0.200
# Accuracy of the network on the train images after epoch 29 is 86.90857346140163
# Accuracy of the network on the test images: 74 %
# Finished Training

# %%
import seaborn as sns
# prepare to count predictions for each class
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}
num_classes = len(classes)
cm = torch.zeros(num_classes, num_classes)

# again no gradients needed
with torch.no_grad():
    for data in testloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = net(inputs)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1
            cm[label, prediction] = cm[label, prediction] + 1

# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print("Accuracy for class {:5s} is: {:.1f} %".format(classname,
                                                   accuracy))
    
fig = plt.figure(figsize=(10, 8))
confusionMatrix = cm.numpy()
confusionMatrix = confusionMatrix / confusionMatrix.astype(np.float).sum(axis=1, keepdims=True)
hmap = sns.heatmap(confusionMatrix , annot=True,
          fmt='.2', cmap='Blues', annot_kws={"size": 6},xticklabels=[0,1], yticklabels=[0,1])
hmap.set_xticklabels(hmap.get_xmajorticklabels(), fontsize=6)
hmap.set_yticklabels(hmap.get_ymajorticklabels(), fontsize=6)
figure = hmap.get_figure()
plt.show()
# Out:
# Accuracy for class Indian_numpy is: 70.4 %
# Accuracy for class Western_numpy is: 77.9 %

# %%
correct_pred = {classname: 0 for classname in classes}
total_pred = {classname: 0 for classname in classes}
num_classes = len(classes)
cm = torch.zeros(num_classes, num_classes)

# again no gradients needed
with torch.no_grad():
    for data in trainloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = net(inputs)
        _, predictions = torch.max(outputs, 1)
        # collect the correct predictions for each class
        for label, prediction in zip(labels, predictions):
            if label == prediction:
                correct_pred[classes[label]] += 1
            total_pred[classes[label]] += 1
            cm[label, prediction] = cm[label, prediction] + 1

# print accuracy for each class
for classname, correct_count in correct_pred.items():
    accuracy = 100 * float(correct_count) / total_pred[classname]
    print("Accuracy for class {:5s} is: {:.1f} %".format(classname,
                                                   accuracy))
    
fig = plt.figure(figsize=(10, 8))
confusionMatrix = cm.numpy()
confusionMatrix = confusionMatrix / confusionMatrix.astype(np.float).sum(axis=1, keepdims=True)
hmap = sns.heatmap(confusionMatrix , annot=True,
          fmt='.2', cmap='Blues', annot_kws={"size": 6},xticklabels=[0,1], yticklabels=[0,1])
hmap.set_xticklabels(hmap.get_xmajorticklabels(), fontsize=6)
hmap.set_yticklabels(hmap.get_ymajorticklabels(), fontsize=6)
figure = hmap.get_figure()
plt.show()
# Out:
# Accuracy for class Indian_numpy is: 89.8 %
# Accuracy for class Western_numpy is: 91.8 %

# %%
classes
# Out:
# ('Indian_numpy', 'Western_numpy')
