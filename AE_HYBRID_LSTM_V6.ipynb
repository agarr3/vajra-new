# %% [markdown]
# <a href="https://colab.research.google.com/github/agarr3/vajra-new/blob/main/AE_HYBRID_LSTM_V6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from tqdm import tqdm_notebook as tqdm
from sklearn.preprocessing import LabelEncoder
from PIL import Image
import matplotlib.pyplot as plt
import torch
# Neural networks can be constructed using the torch.nn package.
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data.sampler import SubsetRandomSampler
from torch.utils.data import Dataset
import torchvision
import torchvision.transforms as transforms

import IPython.display as ipd

import random

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#settings
batch_size = 64
validation_split = .3
shuffle_dataset = True
random_seed= 42
reduction_loss = "mean"
if reduction_loss == "mean":
  criterion = nn.MSELoss(reduction="mean")
elif reduction_loss == "sum":
  criterion = nn.MSELoss(reduction="sum")
n_epochs = 30
print_every = 1

BASE_PATH = "/content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA"

input_bins = 12
seq_len=200
AE_encoded_dim = 64

class_level_loss_mode = "test"

print(device)
# Out:
# cuda:0

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
DATA_BASE_PATH = "/content/gdrive/My Drive/vajra/songs-vajra-data/"
DATA_SONG_DIR = "Chroma"
DATA_IMG_DIR = "Chroma"



files = []
western_files = []
exclusion = ["098567.npy","098569.npy", '098565.npy']
for r,d, fileList in os.walk(os.path.join(DATA_BASE_PATH, DATA_IMG_DIR, "Western_numpy")):
  for file in fileList:
    if(file not in exclusion):
      western_files.append([file,file, "Western_numpy"])
    else:
      print(file)

random.seed(1234)
western_files = random.sample(western_files, 2008)

indian_files = []
for r,d, fileList in os.walk(os.path.join(DATA_BASE_PATH, DATA_IMG_DIR, "Indian_numpy")):
  for file in fileList:
    if(True):
      indian_files.append([file,file, "Indian_numpy"])
    else:
      print(file)

files = indian_files + western_files
dataDF = pd.DataFrame(files, columns=['Images','songs','labels'])
dataDF.head()
# Out:
# 098567.npy
# 098569.npy
# 098565.npy
#                   Images                  songs        labels
# 0           Theeyame.npy           Theeyame.npy  Indian_numpy
# 1    AadedaAattamNee.npy    AadedaAattamNee.npy  Indian_numpy
# 2    ElampadiElelelo.npy    ElampadiElelelo.npy  Indian_numpy
# 3  SajanMoreGharAaye.npy  SajanMoreGharAaye.npy  Indian_numpy
# 4         Aanandhame.npy         Aanandhame.npy  Indian_numpy

# %%
if class_level_loss_mode == "all":
  indian_dataDF = pd.DataFrame(indian_files, columns=['Images','songs','labels'])
  indian_dataDF.head()
elif class_level_loss_mode == "test":
  indian_dataDF = dataDF[dataDF['labels'] == "Indian_numpy"]
  indian_dataDF = indian_dataDF.reset_index(drop=True)

# %%
if class_level_loss_mode == "all":
  western_dataDF = pd.DataFrame(western_files, columns=['Images','songs','labels'])
  western_dataDF.head()
elif class_level_loss_mode == "test":
  western_dataDF = dataDF[dataDF['labels'] == "Western_numpy"]
  western_dataDF = western_dataDF.reset_index(drop=True)

# %%
western_dataDF.groupby("labels").count()
# Out:
#                Images  songs
# labels
# Western_numpy    2008   2008

# %%
dataDF.groupby("labels").count()
# Out:
#                Images  songs
# labels
# Indian_numpy     2008   2008
# Western_numpy    2008   2008

# %%
test_idx = random. randint(0,1000)
test_img_path = os.path.join(DATA_BASE_PATH, DATA_IMG_DIR, dataDF.loc[test_idx, 'labels'], dataDF.loc[test_idx, 'Images'])
print(test_img_path)

numpy_arr = np.load(test_img_path)

import matplotlib.pyplot as plt

plt.pcolormesh(numpy_arr)
# Out:
# /content/gdrive/My Drive/vajra/songs-vajra-data/Chroma/Indian_numpy/RangeWalaJatt.npy

# %%
test_img_path = '/content/gdrive/My Drive/Kaggle/GTZAN/Data/images_original/reggae/reggae00016.png'
test_image = Image.open(test_img_path)
test_image = test_image.convert('RGB').convert('L')
test_image
# Out:
# <PIL.Image.Image image mode=L size=432x288 at 0x7FE203C1FA10>

# %%
lb = LabelEncoder()
dataDF['encoded_labels'] = lb.fit_transform(dataDF['labels'])
dataDF.head()
# Out:
#                   Images                  songs        labels  encoded_labels
# 0           Theeyame.npy           Theeyame.npy  Indian_numpy               0
# 1    AadedaAattamNee.npy    AadedaAattamNee.npy  Indian_numpy               0
# 2    ElampadiElelelo.npy    ElampadiElelelo.npy  Indian_numpy               0
# 3  SajanMoreGharAaye.npy  SajanMoreGharAaye.npy  Indian_numpy               0
# 4         Aanandhame.npy         Aanandhame.npy  Indian_numpy               0

# %%
indian_dataDF['encoded_labels'] = lb.transform(indian_dataDF['labels'])
western_dataDF['encoded_labels'] = lb.transform(western_dataDF['labels'])

# %%
indian_dataDF.groupby(by=['labels','encoded_labels']).count()
# Out:
#                              Images  songs
# labels       encoded_labels
# Indian_numpy 0                 2008   2008

# %%
classes = ('Indian_numpy', 'Western_numpy')
dataDF.groupby(by=['labels','encoded_labels']).count()
# Out:
#                               Images  songs
# labels        encoded_labels
# Indian_numpy  0                 2008   2008
# Western_numpy 1                 2008   2008

# %%
from sklearn.model_selection import train_test_split

dataDF = dataDF.sample(frac=1)
df_train, df_test = train_test_split(dataDF, test_size=validation_split, stratify=dataDF[["labels"]], random_state=9)

df_train = df_train.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)


if class_level_loss_mode == "test":
  western_dataDF = df_test[df_test['labels'] == "Western_numpy"]
  western_dataDF = western_dataDF.reset_index(drop=True)
  indian_dataDF = df_test[df_test['labels'] == "Indian_numpy"]
  indian_dataDF = indian_dataDF.reset_index(drop=True)

# %%
df_train.groupby(by=['labels','encoded_labels']).count()
# Out:
#                               Images  songs
# labels        encoded_labels
# Indian_numpy  0                 1405   1405
# Western_numpy 1                 1406   1406

# %%
df_test.groupby(by=['labels','encoded_labels']).count()
# Out:
#                               Images  songs
# labels        encoded_labels
# Indian_numpy  0                  603    603
# Western_numpy 1                  602    602

# %%
indian_dataDF.groupby(by=['labels','encoded_labels']).count()
# Out:
#                              Images  songs
# labels       encoded_labels
# Indian_numpy 0                  603    603

# %%
transform_normal = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

transform = transforms.Compose(
    [transforms.ToTensor()])

# %%
class MEL_Dataset(Dataset):
    def __init__(self, img_data,img_path,transform=None):
        self.img_path = img_path
        self.transform = transform
        self.img_data = img_data
        
    def __len__(self):
        return len(self.img_data)
    
    def __getitem__(self, index):
        img_name = os.path.join(self.img_path,self.img_data.loc[index, 'labels'],
                                self.img_data.loc[index, 'Images'])
        image = np.load(img_name)
        data = torch.tensor(image[:,:seq_len], dtype=torch.float)
        data = data.permute(1, 0)
        label = torch.tensor(self.img_data.loc[index, 'encoded_labels'])
        fileName = self.img_data.loc[index, 'Images']
        return data, label, fileName

# %%
train_dataset = MEL_Dataset(df_train,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)
test_dataset = MEL_Dataset(df_test,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)

# %%
trainloader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size)
testloader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size)

# %%
indian_dataset = MEL_Dataset(indian_dataDF,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)
western_dataset = MEL_Dataset(western_dataDF,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)

indian_loader = torch.utils.data.DataLoader(indian_dataset, batch_size=batch_size)
western_loader = torch.utils.data.DataLoader(western_dataset, batch_size=batch_size)

# %%
len(indian_dataset)
# Out:
# 603

# %%
def mel_display(S_DB):
    S_DB = S_DB.numpy()
    array = S_DB*-1
    array *= (255.0/array.max())
    #array = 255 - array
    array = np.transpose(array, (2, 1, 0))
    return array.squeeze()

# %%
# get some random training images
dataiter = iter(trainloader)
images, labels, fileNames = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label, fileName = images[i], labels[i], fileNames[i]
        ax.pcolormesh(image.permute(1, 0)) # add image
        ax.set(title = f"\n \n {arthopod_types[label.item()]} - \n {fileName}") # add label

# %%
# get some random training images
dataiter = iter(testloader)
images, labels, fileNames = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        ax.pcolormesh(image.permute(1, 0)) # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
# get some random training images
dataiter = iter(indian_loader)
images, labels, fileNames = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        ax.pcolormesh(image.permute(1, 0)) # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
# get some random training images
dataiter = iter(western_loader)
images, labels, fileNames = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        ax.pcolormesh(image.permute(1, 0)) # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
class Encoder(torch.nn.Module):
  def __init__(self, seq_len, n_features, embedding_dim=64, kernel_size=[4,3,2], stride=[1,1,1]):
    super(Encoder, self).__init__()
    self.seq_len, self.n_features = seq_len, n_features
    self.embedding_dim, self.hidden_dim = embedding_dim, 2 * embedding_dim


    self.conv = nn.Conv1d(in_channels=seq_len,out_channels=seq_len,kernel_size=kernel_size[0],stride=stride[0], groups=seq_len)
    conv_op_dim = int(((n_features - kernel_size[0])/ stride[0]) + 1)

    self.conv_1 = nn.Conv1d(in_channels=seq_len,out_channels=seq_len,kernel_size=kernel_size[1],stride=stride[1], groups=seq_len)
    conv_op_dim1 = int(((conv_op_dim - kernel_size[1])/ stride[1]) + 1)

    self.conv_2 = nn.Conv1d(in_channels=seq_len,out_channels=seq_len,kernel_size=kernel_size[2],stride=stride[2], groups=seq_len)
    conv_op_dim2 = int(((conv_op_dim1 - kernel_size[2])/ stride[2]) + 1)

    self.rnn1 = nn.LSTM(
      input_size=conv_op_dim2,
      hidden_size=self.hidden_dim,
      num_layers=1,
      batch_first=True
    )
    self.rnn2 = nn.LSTM(
      input_size=self.hidden_dim,
      hidden_size=embedding_dim,
      num_layers=1,
      batch_first=True
    )
  def forward(self, x):
    x = self.conv(x)
    x = self.conv_1(x)
    x = self.conv_2(x)
    lstm_l1_op, (_, _) = self.rnn1(x)
    lstm_l2_op, (hidden_n, _) = self.rnn2(lstm_l1_op)
    return lstm_l2_op, lstm_l1_op

class Decoder(torch.nn.Module):
  def __init__(self, seq_len, embedding_dim=64, n_features=26):
    super(Decoder, self).__init__()
    self.seq_len, self.embedding_dim = seq_len, embedding_dim
    self.hidden_dim, self.n_features = 2 * embedding_dim, n_features
    self.rnn1 = nn.LSTM(
      input_size=embedding_dim,
      hidden_size=embedding_dim,
      num_layers=1,
      batch_first=True
    )
    self.rnn2 = nn.LSTM(
      input_size=embedding_dim,
      hidden_size=self.hidden_dim,
      num_layers=1,
      batch_first=True
    )
    self.output_layer = nn.Linear(self.hidden_dim * self.seq_len, n_features * self.seq_len)
  def forward(self, x):
    x, (hidden_n, cell_n) = self.rnn1(x)
    x, (hidden_n, cell_n) = self.rnn2(x)
    x = x.contiguous()
    x = x.view(x.shape[0], -1)
    x = self.output_layer(x)
    return x.reshape(x.shape[0],self.seq_len, self.n_features)

class RecurrentAutoencoder(torch.nn.Module):
  def __init__(self, seq_len, n_features, embedding_dim=64, device='cpu'):
    super(RecurrentAutoencoder, self).__init__()
    self.encoder = Encoder(seq_len, n_features, embedding_dim).to(device)
    self.decoder = Decoder(seq_len, embedding_dim, n_features).to(device)
  def forward(self, x):
    x, l1_op = self.encoder(x)
    x = self.decoder(x)
    return x

net = RecurrentAutoencoder(seq_len, input_bins, AE_encoded_dim, device=device)
net.to(device)
# Out:
# RecurrentAutoencoder(
#   (encoder): Encoder(
#     (conv): Conv1d(200, 200, kernel_size=(4,), stride=(1,), groups=200)
#     (conv_1): Conv1d(200, 200, kernel_size=(3,), stride=(1,), groups=200)
#     (conv_2): Conv1d(200, 200, kernel_size=(2,), stride=(1,), groups=200)
#     (rnn1): LSTM(6, 128, batch_first=True)
#     (rnn2): LSTM(128, 64, batch_first=True)
#   )
#   (decoder): Decoder(
#     (rnn1): LSTM(64, 64, batch_first=True)
#     (rnn2): LSTM(64, 128, batch_first=True)
#     (output_layer): Linear(in_features=25600, out_features=2400, bias=True)
#   )
# )

# %%
optimizer = torch.optim.Adam(net.parameters(), lr=0.001)

# %%
import matplotlib.pyplot as plt
import numpy as np

def visualize(train_loss_graph, test_loss_graph):
  x = range(len(train_loss_graph))
      
  # plot lines
  plt.plot(x, train_loss_graph, label = "Training Loss")
  plt.plot(x, test_loss_graph, label = "Test Loss")
  
  plt.legend()
  plt.show()

def visualize_class_loss(in_loss_graph, we_loss_graph):
  x = range(len(in_loss_graph))
      
  # plot lines
  plt.plot(x, in_loss_graph, label = "Indian Loss")
  plt.plot(x, we_loss_graph, label = "Western Loss")
  
  plt.legend()
  plt.show()

# %%
train_loss_graph = []
test_loss_graph = []
best_loss = np.Inf

indian_loss_graph = []
western_loss_graph = []

for epoch in range(n_epochs):  # loop over the dataset multiple times

    running_loss = 0.0
    total_Loss = 0.0
    correct = 0
    total = 0
    for i, data in enumerate(trainloader, 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels, fileNames = data
        inputs, labels = inputs.to(device), labels.to(device)

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, inputs)
        loss.backward()
        optimizer.step()

        # print statistics
        running_loss += loss.item()
        total_Loss += loss.item()

        if i % print_every == 0:    # print every 2000 mini-batches
            print('[%d, %5d] loss: %.3f' %
                  (epoch + 1, i + 1, running_loss / print_every))
            running_loss = 0.0
    
    print('LOSS of the network on the train images after epoch {} is {}'.format(epoch, total_Loss) )
    if reduction_loss == "mean":
      total_Loss = total_Loss/i
      print('Mean of the network on the train images after epoch {} is {}'.format(epoch, total_Loss) )
    
    train_loss_graph.append(total_Loss)
    correct = 0
    total = 0
    running_loss = 0.0
    total_Loss = 0.0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for j, data in enumerate(testloader,0):
            inputs, labels, fileNames = data
            inputs, labels = inputs.to(device), labels.to(device)
            # calculate outputs by running images through the network
            outputs = net(inputs)
            loss = criterion(outputs, inputs)
            running_loss += loss.item()
            total_Loss += loss.item()

    print('LOSS of the network on the test images: %d %%' % (total_Loss))
    if reduction_loss == "mean":
      total_Loss = total_Loss/j
      print('Mean of the network on the train images after epoch {} is {}'.format(epoch, total_Loss) )
    
    test_loss_graph.append(total_Loss)
    visualize(train_loss_graph, test_loss_graph)
    if total_Loss < best_loss:
      best_loss = total_Loss
      torch.save(net.state_dict(), os.path.join(BASE_PATH, "best_model.pt"))

    running_loss = 0.0
    total_Loss = 0.0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for j, data in enumerate(indian_loader,0):
            inputs, labels, fileNames = data
            inputs, labels = inputs.to(device), labels.to(device)
            # calculate outputs by running images through the network
            outputs = net(inputs)
            loss = criterion(outputs, inputs)
            running_loss += loss.item()
            total_Loss += loss.item()

    print('LOSS of the network on the test images: %d %%' % (total_Loss))
    if reduction_loss == "mean":
      total_Loss = total_Loss/j
      print('Mean of the network on the train images after epoch {} is {}'.format(epoch, total_Loss) )

    indian_loss_graph.append(total_Loss)

    running_loss = 0.0
    total_Loss = 0.0
    # since we're not training, we don't need to calculate the gradients for our outputs
    with torch.no_grad():
        for j, data in enumerate(western_loader,0):
            inputs, labels, fileNames = data
            inputs, labels = inputs.to(device), labels.to(device)
            # calculate outputs by running images through the network
            outputs = net(inputs)
            loss = criterion(outputs, inputs)
            running_loss += loss.item()
            total_Loss += loss.item()

    print('LOSS of the network on the test images: %d %%' % (total_Loss))
    if reduction_loss == "mean":
      total_Loss = total_Loss/j
      print('Mean of the network on the train images after epoch {} is {}'.format(epoch, total_Loss) )

    western_loss_graph.append(total_Loss)

    visualize_class_loss(indian_loss_graph, western_loss_graph)
          

print('Finished Training')
# Out:
# [1,     1] loss: 0.123
# [1,     2] loss: 0.094
# [1,     3] loss: 0.120
# [1,     4] loss: 0.146
# [1,     5] loss: 0.125
# [1,     6] loss: 0.102
# [1,     7] loss: 0.095
# [1,     8] loss: 0.095
# [1,     9] loss: 0.112
# [1,    10] loss: 0.119
# [1,    11] loss: 0.116
# [1,    12] loss: 0.105
# [1,    13] loss: 0.094
# [1,    14] loss: 0.093
# [1,    15] loss: 0.097
# [1,    16] loss: 0.103
# [1,    17] loss: 0.098
# [1,    18] loss: 0.104
# [1,    19] loss: 0.098
# [1,    20] loss: 0.095
# [1,    21] loss: 0.093
# [1,    22] loss: 0.095
# [1,    23] loss: 0.095
# [1,    24] loss: 0.099
# [1,    25] loss: 0.096
# [1,    26] loss: 0.096
# [1,    27] loss: 0.092
# [1,    28] loss: 0.095
# [1,    29] loss: 0.094
# [1,    30] loss: 0.093
# [1,    31] loss: 0.093
# [1,    32] loss: 0.092
# [1,    33] loss: 0.095
# [1,    34] loss: 0.094
# [1,    35] loss: 0.095
# [1,    36] loss: 0.091
# [1,    37] loss: 0.094
# [1,    38] loss: 0.094
# [1,    39] loss: 0.097
# [1,    40] loss: 0.096
# [1,    41] loss: 0.094
# [1,    42] loss: 0.097
# [1,    43] loss: 0.094
# [1,    44] loss: 0.093
# LOSS of the network on the train images after epoch 0 is 4.399834841489792
# Mean of the network on the train images after epoch 0 is 0.1023217404997626
# LOSS of the network on the test images: 1 %
# Mean of the network on the train images after epoch 0 is 0.09925533417198393
# LOSS of the network on the test images: 0 %
# Mean of the network on the train images after epoch 0 is 0.10364454984664917
# LOSS of the network on the test images: 0 %
# Mean of the network on the train images after epoch 0 is 0.10548849900563557
# [2,     1] loss: 0.094
# [2,     2] loss: 0.094
# [2,     3] loss: 0.094
# [2,     4] loss: 0.093
# [2,     5] loss: 0.095
# [2,     6] loss: 0.092
# [2,     7] loss: 0.095
# [2,     8] loss: 0.092
# [2,     9] loss: 0.093
# [2,    10] loss: 0.096
# [2,    11] loss: 0.096
# [2,    12] loss: 0.094
# [2,    13] loss: 0.093
# [2,    14] loss: 0.093
# [2,    15] loss: 0.094
# [2,    16] loss: 0.095
# [2,    17] loss: 0.093
# [2,    18] loss: 0.094
# [2,    19] loss: 0.095
# [2,    20] loss: 0.094
# [2,    21] loss: 0.092
# LOSS of the network on the test images: 0 %
# Mean of the network on the train images after epoch 29 is 0.06635996161235704
# LOSS of the network on the test images: 0 %
# Mean of the network on the train images after epoch 29 is 0.059347053782807455
# Finished Training

# %%
# get some random training images
dataiter = iter(testloader)
images, labels, fileNames = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(3, 5, figsize=(15, 10))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        image, labels = image.to(device), labels.to(device)
        output_img = net(image.unsqueeze(dim=0))
        output_img = output_img.squeeze(dim=0)
        ax.pcolormesh(output_img.detach().cpu().permute(1,0)) # add image
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

# %%
# get some random training images
outputs=[]
dataiter = iter(testloader)
images, labels, fileNames = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(1, 5, figsize=(15, 2))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        image, labels = image.to(device), labels.to(device)
        output_img = net(image.unsqueeze(dim=0))
        output_img = output_img.squeeze(dim=0)
        ax.pcolormesh(output_img.detach().cpu().permute(1,0)) # add image
        outputs.append((image.detach().cpu().permute(1,0).flip(0),arthopod_types[label.item()] ))
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

fig, axis = plt.subplots(1, 5, figsize=(15, 2))
for ax , (image, label) in zip(axis.flat, outputs):
    ax.imshow(image, interpolation='nearest', aspect='auto') # add image
    ax.set(title = f"{label}") # add label

# %%
torch.save(net.state_dict(), os.path.join(BASE_PATH, "final_model.pt"))

# %% [markdown]
# Start evaluation - Test model

# %%
model = RecurrentAutoencoder(seq_len, input_bins, AE_encoded_dim, device=device)
model.load_state_dict(torch.load(os.path.join(BASE_PATH, "best_model.pt"), map_location=device))
# Out:
# <All keys matched successfully>

# %%
# get some random training images
outputs=[]
dataiter = iter(testloader)
images, labels, fileNames = dataiter.next()
arthopod_types = {0: 'Indian_numpy', 1: 'Western_numpy', 2: 'country', 3: 'disco', 4: 'hiphop', 5: 'jazz', 6: 'metal', 7: 'pop', 8: 'reggae', 9: 'rock'}
# Viewing data examples used for training
fig, axis = plt.subplots(1, 5, figsize=(15, 2))
for i, ax in enumerate(axis.flat):
    with torch.no_grad():
        image, label = images[i], labels[i]
        image, labels = image.to(device), labels.to(device)
        output_img = model(image.unsqueeze(dim=0))
        output_img = output_img.squeeze(dim=0)
        ax.pcolormesh(output_img.detach().cpu().permute(1,0).flip(0)) # add image
        outputs.append((image.detach().cpu().permute(1,0),arthopod_types[label.item()] ))
        ax.set(title = f"{arthopod_types[label.item()]}") # add label

fig, axis = plt.subplots(1, 5, figsize=(15, 2))
for ax , (image, label) in zip(axis.flat, outputs):
    ax.imshow(image, interpolation='nearest', aspect='auto') # add image
    ax.set(title = f"{label}") # add label

# %% [markdown]
# Combined data set recinstruction

# %%
combined_dataset = MEL_Dataset(dataDF,os.path.join(DATA_BASE_PATH, DATA_IMG_DIR),transform)
combinedloader = torch.utils.data.DataLoader(combined_dataset, batch_size=batch_size)

# %%
# dataDF
# dataDF.loc[1, 'labels']
# classes
# os.path.join(BASE_PATH, "Activations_64", str(classes[label]))

# %%
for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_64",  str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_128", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "reconstructions", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "originals",  str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

# %%
id = 0
with torch.no_grad():
    for data in combinedloader:
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        output_l2, output_l1 = model.encoder(inputs)
        output = model(inputs)
        output_l2 = output_l2.detach().cpu().numpy()
        output_l1 = output_l1.detach().cpu().numpy()
        output = output.detach().cpu().numpy()
        labels = labels.detach().cpu().numpy()
        
        for  arr64, arr128, arr48, label in zip(output_l2, output_l1, output, labels):
          print(os.path.join(BASE_PATH, "Activations_64", str(classes[label]), str(id) + ".npy"))
          np.save(os.path.join(BASE_PATH, "Activations_64", str(classes[label]), str(id) + ".npy"),np.transpose(arr64, (1,0)))
          np.save(os.path.join(BASE_PATH, "Activations_128", classes[label] ,  str(id) + ".npy" ), np.transpose(arr128, (1,0)))
          np.save(os.path.join(BASE_PATH, "reconstructions", classes[label] ,  str(id) + ".npy"), np.transpose(arr48, (1,0)))
          id = id + 1

# %% [markdown]
# Strict data separation

# %%
for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_64", "test", str(class_))
  #print("removing ", dir)
  for f in os.listdir(dir):
    #print("removing ", os.path.join(dir, f))
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_128", "test", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "reconstructions", "test", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "originals", "test", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))


for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_64", "training", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "Activations_128", "training", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "reconstructions", "training", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

for class_ in classes:
  dir = os.path.join(BASE_PATH, "originals", "training", str(class_))
  for f in os.listdir(dir):
    os.remove(os.path.join(dir, f))

# %%
id_test = 0
with torch.no_grad():
    for data_test in testloader:
        inputs, labels, fileNames = data_test
        inputs, labels = inputs.to(device), labels.to(device)
        output_l2, output_l1 = model.encoder(inputs)
        output = model(inputs)
        output_l2 = output_l2.detach().cpu().numpy()
        output_l1 = output_l1.detach().cpu().numpy()
        output = output.detach().cpu().numpy()
        labels = labels.detach().cpu().numpy()
        inputs = inputs.detach().cpu().numpy()
        
        for  orr48, arr64, arr128, arr48, label, fileName in zip(inputs, output_l2, output_l1, output, labels, fileNames):
          print(os.path.join(BASE_PATH, "Activations_64", "test", str(classes[label]), str(fileName)))
          np.save(os.path.join(BASE_PATH, "Activations_64", "test",str(classes[label]), str(fileName)),np.transpose(arr64, (1,0)))
          np.save(os.path.join(BASE_PATH, "Activations_128", "test",classes[label] ,  str(fileName) ), np.transpose(arr128, (1,0)))
          np.save(os.path.join(BASE_PATH, "reconstructions", "test",classes[label] ,  str(fileName)), np.transpose(arr48, (1,0)))
          np.save(os.path.join(BASE_PATH, "originals", "test",classes[label] ,  str(fileName)), np.transpose(orr48, (1,0)))
          id_test = id_test + 1
# Out:
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/132117.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/123502.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Dard.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/042911.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/076077.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Manguz.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/053586.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/128835.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/PehliMulakaat.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/TenuKaulKe.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/125191.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/126508.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/052646.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/SachiReMari.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/VaaMunimma.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Shokeen.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/086721.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Tareefan.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/038557.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/010679.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/054037.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/YouGetMeRockin&amp;Reeling.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/132041.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/092131.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/053157.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/DerMariAnguthadiNoChor.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/111393.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/074392.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/142533.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/AethuKariRaavilum.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/144552.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/075439.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/006461.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/075927.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/MaariTharaLocal.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/142092.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/054335.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/RagaShuddhKalyan.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/115272.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/TumBepanah.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/JauJahaJahaPauWahaWaha.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/PujniyaMaajisa.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/115925.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/033477.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/018146.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/055714.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/NeeyumNjanum.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/026605.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/KanneThaaiMalare.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Marjaani.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/EiKathatiMoneRekho.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/058543.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/127212.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/135225.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/MoongilKaadugalae.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/138282.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/045101.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Mitwaa.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/046711.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/MitranDeBoot.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/123097.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/036992.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/024983.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/085823.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/128880.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/IAmDogGoneCrazy.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/101951.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/143318.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/048444.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/NrityeroTaleTale.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/ChararChararMaroChakdod.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Yaariyan.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/VicholiyanDeGapp.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/119097.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/AkkamPakkamPaar.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/IshqDiBaajiyaan.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Pachakkarikkaya.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/069761.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/134452.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/123935.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/014733.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/092554.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/JithuJilladi.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/136054.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/RayZRMeraSwag.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/BrahmaBaba.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/ZaraSa.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/EnUiranaYesu.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/075782.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/014317.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/045474.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/MeherHaiRabDi.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/KabhiKhushiKabhieGham.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Fearless.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/037727.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/042376.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/083512.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/ThugLife.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/AasPaasKhuda.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/148586.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/148608.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/KhabarNahi.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Simtaangaran.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/126669.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/025063.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/057164.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/HoldMeNow.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/150266.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/075762.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/126354.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/LalithaSahasranamaSthothram.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/ChinnanChiruPenPole.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/KannaleKollathe.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Hostel.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/125159.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Mungda.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/118085.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/083954.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Empurane.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/NokkiNokki.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/YeReGhana.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/121257.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/034147.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/MuneEkliJanine.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/069785.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/128758.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/MusuMusu.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy
npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/MadhuBrindaboney.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/ElampadiElelelo.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/075374.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/110082.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/056694.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/WakeUpSid!.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/107178.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/066648.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/057820.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/ItsOver.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/107913.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/AyeSinamika.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/AshqNaHo.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/OSnehame.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/TereSharanAayeDekhoAmbeMata.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/MainBhiNahiSoya.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/RagaBhoopali.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Aarariraro.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/091934.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/DeewangiDeewangi.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/120178.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/KumkumPagleMadi.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/132420.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Madari.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/AllimarKavil.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/096697.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/000695.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/065234.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/116880.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/IkkKudi.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/OyaaOyaa.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/SoniDeNakhre.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/SappandePutt.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/021859.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/043843.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/RagaGaudMalhar.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/051268.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/SaajanjiGharAaye.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/048999.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/033124.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/104434.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/TuHiHai.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/DhesayumEzhandheney.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/MatwaroBadal.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/086417.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/123488.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/JaiGaneshJaiGaneshDeva.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/HandRaiser.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/040725.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Harkat.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/134448.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/026012.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/124702.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/046525.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Azhagae.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/TeriMeriTutju.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/096945.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Defaulter.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/098551.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/144423.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/126520.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/NachdiDiGutKulGaye.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/KarGayiChull.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/RudiNeRangiliReVhala.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/113165.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/KataRuteKunala.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/052042.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/145552.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/110439.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/RangloJamyo.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/149141.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/KeBosileyAaji.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/063757.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Aaftaab.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/045391.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/Bullet.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/074954.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/VilambaraIdaiveli.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/127296.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/121256.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/068551.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/080696.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/GerraDeDe.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/CheliyaAdugudhama.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/RemoNeeKadhalan.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/096408.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Western_numpy/084154.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/test/Indian_numpy/KaroKeuNaikoAami.npy

# %%
id_train = 0
with torch.no_grad():
    for data in trainloader:
        inputs, labels, fileNames = data
        inputs, labels = inputs.to(device), labels.to(device)
        output_l2, output_l1 = model.encoder(inputs)
        output = model(inputs)
        output_l2 = output_l2.detach().cpu().numpy()
        output_l1 = output_l1.detach().cpu().numpy()
        output = output.detach().cpu().numpy()
        labels = labels.detach().cpu().numpy()
        inputs = inputs.detach().cpu().numpy()
        
        for  orr48, arr64, arr128, arr48, label, fileName in zip(inputs, output_l2, output_l1, output, labels, fileNames):
          print(os.path.join(BASE_PATH, "Activations_64", "training", str(classes[label]), str(fileName)))
          np.save(os.path.join(BASE_PATH, "Activations_64", "training",str(classes[label]), str(fileName)),np.transpose(arr64, (1,0)))
          np.save(os.path.join(BASE_PATH, "Activations_128", "training",classes[label] ,  str(fileName) ), np.transpose(arr128, (1,0)))
          np.save(os.path.join(BASE_PATH, "reconstructions", "training",classes[label] ,  str(fileName)), np.transpose(arr48, (1,0)))
          np.save(os.path.join(BASE_PATH, "originals", "training",classes[label] ,  str(fileName)), np.transpose(orr48, (1,0)))
          id_train = id_train + 1
# Out:
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/116407.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/VilagaadheEnadhuyirae.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/VadaladiVarsiRe.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/AthmavinAkashathil.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/MayaNadhi.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/EkVanzariZulan.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/096693.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/YoureSoBeautiful.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/SinglePasanga.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/KrishnaKoli.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/128666.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/BasoBasoMere.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/062192.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/099389.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/Kaatil.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/SheyDinDujoney.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/150017.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/MailiChadar.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/FolkMelodyBasedonRagaDes.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/ViruttamFollowedByVilaiyadaIduNerama.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/Bolna.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/080003.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/107616.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/GotItAll.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/142568.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Western_numpy/152480.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy/PudhuMetroRail.npy
# /content/gdrive/My Drive/vajra/AE_HYBRID_LSTM_V1/CHROMA/Activations_64/training/Indian_numpy